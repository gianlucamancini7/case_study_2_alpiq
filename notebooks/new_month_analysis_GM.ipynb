# %%
#include autoreload modules for fast testing and update
# %load_ext autoreload
# %autoreload 2

#import relevant modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

#import modules
from src.data.helper_closed_transactions import read_epex_file, filter_lead_time, extract_transactions
from src.data.welfare_complete import read_pw_file, pw_preparation, read_weekly_prices_file

#set maximum columns display pandas
pd.options.display.max_columns = 50
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Read new version of the excel transactions

# %%
tic=time.time()
path='../data/external/prepared_EPEX_2019_Nov_Dec/ID_GDM_2019_11_01_11.csv'
cols = list(pd.read_csv(path, nrows=1))
df=pd.read_csv(path,
              usecols=[i for i in cols if 'Unnamed' not in i])
toc=time.time()

# %%
def isTimeFormat(input):
    try:
        time.strptime(input, '%m/%d/%y %H:%M')
        return True
    except ValueError:
        return False

# %%
#format time presenting hour as well
df['problem_from_time']=df['FROM_TIME'].apply(lambda x: isTimeFormat(x) )
df['problem_to_time']=df['TO_TIME'].apply(lambda x: isTimeFormat(x))
df['problem_timestamp']=df['TIMESTAMP'].apply(lambda x: isTimeFormat(x))
df['FROM_TIME']=df['FROM_TIME'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')
df['TO_TIME']=df['TO_TIME'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')
df['TIMESTAMP']=df['TIMESTAMP'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')

# %%
df['FROM_TIME']=pd.to_datetime(df['FROM_TIME'],format='%m/%d/%y %H:%M')
df['TO_TIME']=pd.to_datetime(df['TO_TIME'],format='%m/%d/%y %H:%M')
df['TIMESTAMP']=pd.to_datetime(df['TIMESTAMP'],format='%m/%d/%y %H:%M')

# %% [markdown]
# Check when the problems occur. There are now rows which present both problems

# %%
df[(df['problem_from_time']==False)&(df['problem_to_time']==False)]
# Out:
# Empty DataFrame
# Columns: [DLVRYDATE, MARKET_AREA_BUY, MARKET_AREA_SELL, FROM_TIME, TO_TIME, VOLUME, PRICE, TIMESTAMP, TRADE_ID, DURATION, PROD, problem_from_time, problem_to_time, problem_timestamp]
# Index: []

# %%
df[df['problem_timestamp']==False]
# Out:
#        DLVRYDATE MARKET_AREA_BUY MARKET_AREA_SELL           FROM_TIME  \
# 75574    11/8/19              DE               DE 2019-11-08 10:00:00
# 75575    11/8/19              DE               DE 2019-11-08 10:00:00
# 75576    11/8/19              DE               DE 2019-11-08 10:00:00
# 75577    11/8/19              DE               DE 2019-11-08 10:00:00
# 75578    11/8/19              DE               DE 2019-11-08 10:00:00
# 75579    11/8/19              DE               DE 2019-11-08 10:00:00
# 75580    11/8/19              DE               DE 2019-11-08 10:00:00
# 75581    11/8/19              DE               DE 2019-11-08 10:00:00
# 186629   11/5/19              DE               DE 2019-11-05 00:15:00
# 186630   11/5/19              DE               DE 2019-11-05 00:15:00
# 186631   11/5/19              DE               DE 2019-11-05 01:00:00
# 186632   11/5/19              DE               DE 2019-11-05 01:00:00
# 248005   11/8/19              DE               DE 2019-11-08 20:30:00
# 433674   11/5/19              DE               DE 2019-11-05 16:00:00
#
#                    TO_TIME  VOLUME  PRICE  TIMESTAMP    TRADE_ID  DURATION  \
# 75574  2019-11-08 11:00:00     1.6  58.20 2019-11-08  1081700011      1.00
# 75575  2019-11-08 11:00:00     7.0  58.21 2019-11-08  1081700013      1.00
# 75576  2019-11-08 11:00:00    11.6  58.00 2019-11-08  1081700014      1.00
# 75577  2019-11-08 11:00:00     6.0  58.00 2019-11-08  1081700015      1.00
# 75578  2019-11-08 11:00:00     1.0  58.00 2019-11-08  1081700016      1.00
# 75579  2019-11-08 11:00:00     3.3  57.80 2019-11-08  1081700017      1.00
# 75580  2019-11-08 11:00:00    33.0  58.00 2019-11-08  1081700019      1.00
# 75581  2019-11-08 11:00:00     6.6  58.90 2019-11-08  1081700021      1.00
# 186629 2019-11-05 00:30:00     0.1  28.00 2019-11-05  1081367179      0.25
# 186630 2019-11-05 00:30:00     0.1  30.00 2019-11-05  1081367180      0.25
# 186631 2019-11-05 01:15:00     1.0  35.87 2019-11-05  1081367231      0.25
# 186632 2019-11-05 01:15:00     0.5  35.87 2019-11-05  1081367232      0.25
# 248005 2019-11-08 20:45:00     1.0  60.70 2019-11-08  1081758503      0.25
# 433674 2019-11-05 17:00:00     0.6  52.00 2019-11-05  1081425632      1.00
#
#                                PROD  problem_from_time  problem_to_time  \
# 75574           Intraday_Hour_Power               True             True
# 75575           Intraday_Hour_Power               True             True
# 75576           Intraday_Hour_Power               True             True
# 75577           Intraday_Hour_Power               True             True
# 75578           Intraday_Hour_Power               True             True
# 75579           Intraday_Hour_Power               True             True
# 75580           Intraday_Hour_Power               True             True
# 75581           Intraday_Hour_Power               True             True
# 186629  Intraday_Quarter_Hour_Power               True             True
# 186630  Intraday_Quarter_Hour_Power               True             True
# 186631  Intraday_Quarter_Hour_Power               True             True
# 186632  Intraday_Quarter_Hour_Power               True             True
# 248005  Intraday_Quarter_Hour_Power               True             True
# 433674              XBID_Hour_Power               True             True
#
#         problem_timestamp
# 75574               False
# 75575               False
# 75576               False
# 75577               False
# 75578               False
# 75579               False
# 75580               False
# 75581               False
# 186629              False
# 186630              False
# 186631              False
# 186632              False
# 248005              False
# 433674              False

# %% [markdown]
# Drop rows with date problem being timestamp

# %%
df=df[df['problem_timestamp']]

# %%
def correct_to_time(problem, to_time, from_time, duration):
    
    if not problem:
        return from_time + pd.Timedelta(duration, unit='hours')
    else:
        return to_time

def correct_from_time(problem, to_time, from_time, duration):
    
    if not problem:
        return to_time - pd.Timedelta(duration, unit='hours')
    else:
        return from_time

# %%
#modify dates mistakes
df['FROM_TIME']=df.apply(lambda x: correct_from_time(x['problem_from_time'],x['TO_TIME'],x['FROM_TIME'], x['DURATION']), axis=1)
df['TO_TIME']=df.apply(lambda x: correct_to_time(x['problem_to_time'],x['TO_TIME'],x['FROM_TIME'], x['DURATION']), axis=1)

# %%
df.head()
# Out:
#   DLVRYDATE MARKET_AREA_BUY MARKET_AREA_SELL           FROM_TIME  \
# 0   11/2/19              DE               DE 2019-11-02 06:30:00
# 1   11/2/19              DE               DE 2019-11-02 06:30:00
# 2   11/2/19              DE               DE 2019-11-02 09:30:00
# 3   11/2/19              DE               DE 2019-11-02 09:30:00
# 4   11/2/19              DE               DE 2019-11-02 09:30:00
#
#               TO_TIME  VOLUME  PRICE           TIMESTAMP    TRADE_ID  \
# 0 2019-11-02 07:00:00     1.0  15.30 2019-11-02 05:35:00  1081040362
# 1 2019-11-02 07:00:00     1.0  13.02 2019-11-02 05:35:00  1081040372
# 2 2019-11-02 10:00:00     1.5  30.14 2019-11-02 08:38:00  1081055751
# 3 2019-11-02 10:00:00     0.4  31.49 2019-11-02 08:39:00  1081055853
# 4 2019-11-02 10:00:00     1.5  31.75 2019-11-02 08:39:00  1081055864
#
#    DURATION                      PROD  problem_from_time  problem_to_time  \
# 0       0.5  Intraday_Half_Hour_Power               True             True
# 1       0.5  Intraday_Half_Hour_Power               True             True
# 2       0.5  Intraday_Half_Hour_Power               True             True
# 3       0.5  Intraday_Half_Hour_Power               True             True
# 4       0.5  Intraday_Half_Hour_Power               True             True
#
#    problem_timestamp
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %% [markdown]
# Check the correction has happened

# %%
df[df['problem_to_time']==False]
# Out:
#        DLVRYDATE MARKET_AREA_BUY MARKET_AREA_SELL           FROM_TIME  \
# 9456     11/1/19              DE               DE 2019-11-01 20:00:00
# 9457     11/1/19              DE               DE 2019-11-01 20:00:00
# 9458     11/1/19              DE               DE 2019-11-01 20:00:00
# 9459     11/1/19              DE               DE 2019-11-01 20:00:00
# 9460     11/1/19              DE               DE 2019-11-01 20:00:00
# ...          ...             ...              ...                 ...
# 830704  11/10/19              DE               DE 2019-11-10 23:00:00
# 830705  11/10/19              DE               DE 2019-11-10 23:30:00
# 830706  11/10/19              DE               DE 2019-11-10 23:00:00
# 830707  11/10/19              DE               DE 2019-11-10 23:00:00
# 830708  11/10/19              DE               DE 2019-11-10 23:45:00
#
#                    TO_TIME  VOLUME  PRICE           TIMESTAMP    TRADE_ID  \
# 9456   2019-11-01 21:00:00     1.0  38.07 2019-11-01 19:07:00  1080995314
# 9457   2019-11-01 21:00:00     0.7  35.11 2019-11-01 19:07:00  1080995332
# 9458   2019-11-01 21:00:00     0.7  36.98 2019-11-01 19:07:00  1080995363
# 9459   2019-11-01 21:00:00     0.3  36.99 2019-11-01 19:07:00  1080995364
# 9460   2019-11-01 21:00:00     1.0  36.03 2019-11-01 19:08:00  1080995394
# ...                    ...     ...    ...                 ...         ...
# 830704 2019-11-10 23:15:00     4.0  50.19 2019-11-10 21:50:00  1081964782
# 830705 2019-11-10 23:45:00     4.0  37.54 2019-11-10 21:50:00  1081964783
# 830706 2019-11-10 23:15:00     3.4  50.19 2019-11-10 21:50:00  1081964784
# 830707 2019-11-10 23:15:00     0.6  50.20 2019-11-10 21:50:00  1081964785
# 830708 2019-11-11 00:00:00     4.0  33.54 2019-11-10 21:51:00  1081964843
#
#         DURATION                     PROD  problem_from_time  problem_to_time  \
# 9456        1.00      Intraday_Hour_Power               True            False
# 9457        1.00      Intraday_Hour_Power               True            False
# 9458        1.00      Intraday_Hour_Power               True            False
# 9459        1.00      Intraday_Hour_Power               True            False
# 9460        1.00      Intraday_Hour_Power               True            False
# ...          ...                      ...                ...              ...
# 830704      0.25  XBID_Quarter_Hour_Power               True            False
# 830705      0.25  XBID_Quarter_Hour_Power               True            False
# 830706      0.25  XBID_Quarter_Hour_Power               True            False
# 830707      0.25  XBID_Quarter_Hour_Power               True            False
# 830708      0.25  XBID_Quarter_Hour_Power               True            False
#
#         problem_timestamp
# 9456                 True
# 9457                 True
# 9458                 True
# 9459                 True
# 9460                 True
# ...                   ...
# 830704               True
# 830705               True
# 830706               True
# 830707               True
# 830708               True
#
# [19915 rows x 14 columns]

# %% [markdown]
# Check lead time

# %%
df['lead_time']=df['FROM_TIME']-df['TIMESTAMP']

# %%
lead_time_anal=df['lead_time'].dt.total_seconds()/60
lead_time_anal.max()
# Out:
# 1903.0

# %% [markdown]
# The transactions have to be filtered

# %%
# define logical statement to filter rows based on lead time
logical_statement_lead_time = (df['lead_time'].dt.total_seconds(
)/60 >= 30) & (df['lead_time'].dt.total_seconds()/60 <= 60)

# filter the dataframe based on logical statement
df_filtered = df[logical_statement_lead_time]

# %%
lead_time_anal=df_filtered['lead_time'].dt.total_seconds()/60

# %%
lead_time_anal.min()
# Out:
# 30.0

# %%
lead_time_anal.max()
# Out:
# 60.0

# %% [markdown]
# Now change columns' names to make them match with the normal welfare matching

# %%
df_filtered['DURATION'].value_counts()
# Out:
# 0.25    110769
# 1.00     81820
# 0.50       128
# Name: DURATION, dtype: int64

# %%
def map_duration(duration):
    
    d={0.25:'Quarter Hour', 0.5:'Half Hour', 1:'Hour'}
    
    return d[duration]

# %%
df_filtered['End Validity Date']=df_filtered['TIMESTAMP']
df_filtered['Execution Price']=df_filtered['PRICE']
df_filtered['Executed Volume']=df_filtered['VOLUME']
df_filtered['Delivery Start']=df_filtered['FROM_TIME']
df_filtered['Instrument Type']=df_filtered['DURATION'].apply(lambda x: map_duration(x))
# Out:
# <ipython-input-34-a9403d454d41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['End Validity Date']=df_filtered['TIMESTAMP']
# <ipython-input-34-a9403d454d41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Execution Price']=df_filtered['PRICE']
# <ipython-input-34-a9403d454d41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Executed Volume']=df_filtered['VOLUME']
# <ipython-input-34-a9403d454d41>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Delivery Start']=df_filtered['FROM_TIME']
# <ipython-input-34-a9403d454d41>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Instrument Type']=df_filtered['DURATION'].apply(lambda x: map_duration(x))

# %%
df_filtered.head()
# Out:
#   DLVRYDATE MARKET_AREA_BUY MARKET_AREA_SELL           FROM_TIME  \
# 0   11/2/19              DE               DE 2019-11-02 06:30:00
# 1   11/2/19              DE               DE 2019-11-02 06:30:00
# 2   11/2/19              DE               DE 2019-11-02 09:30:00
# 3   11/2/19              DE               DE 2019-11-02 09:30:00
# 4   11/2/19              DE               DE 2019-11-02 09:30:00
#
#               TO_TIME  VOLUME  PRICE           TIMESTAMP    TRADE_ID  \
# 0 2019-11-02 07:00:00     1.0  15.30 2019-11-02 05:35:00  1081040362
# 1 2019-11-02 07:00:00     1.0  13.02 2019-11-02 05:35:00  1081040372
# 2 2019-11-02 10:00:00     1.5  30.14 2019-11-02 08:38:00  1081055751
# 3 2019-11-02 10:00:00     0.4  31.49 2019-11-02 08:39:00  1081055853
# 4 2019-11-02 10:00:00     1.5  31.75 2019-11-02 08:39:00  1081055864
#
#    DURATION                      PROD  problem_from_time  problem_to_time  \
# 0       0.5  Intraday_Half_Hour_Power               True             True
# 1       0.5  Intraday_Half_Hour_Power               True             True
# 2       0.5  Intraday_Half_Hour_Power               True             True
# 3       0.5  Intraday_Half_Hour_Power               True             True
# 4       0.5  Intraday_Half_Hour_Power               True             True
#
#    problem_timestamp       lead_time   End Validity Date  Execution Price  \
# 0               True 0 days 00:55:00 2019-11-02 05:35:00            15.30
# 1               True 0 days 00:55:00 2019-11-02 05:35:00            13.02
# 2               True 0 days 00:52:00 2019-11-02 08:38:00            30.14
# 3               True 0 days 00:51:00 2019-11-02 08:39:00            31.49
# 4               True 0 days 00:51:00 2019-11-02 08:39:00            31.75
#
#    Executed Volume      Delivery Start Instrument Type
# 0              1.0 2019-11-02 06:30:00       Half Hour
# 1              1.0 2019-11-02 06:30:00       Half Hour
# 2              1.5 2019-11-02 09:30:00       Half Hour
# 3              0.4 2019-11-02 09:30:00       Half Hour
# 4              1.5 2019-11-02 09:30:00       Half Hour

# %% [markdown]
# Split the document in different days and apply to the the second part of the pipeline

# %%
df_filtered['FROM_TIME'].dt.day.min()
# Out:
# 1

# %%
df_filtered['FROM_TIME'].dt.day.max()
# Out:
# 10

# %%
def split_daily_transactions(df):
    
    min_date_day=df['FROM_TIME'].dt.day.min()
    max_date_day=df['FROM_TIME'].dt.day.max()
    month=str(df['FROM_TIME'].dt.month.iloc[0])
    
    df_list=[]
    file_names=[]
    for day in range(min_date_day, max_date_day+1):
        
        df_day=df[df['FROM_TIME'].dt.day==day]
        df_list.append(df_day)
        
        day_string=str(day) if len(str(day))==2 else '0'+str(day)
        name='2019'+month+day_string
        file_names.append(name)
    
    return df_list, file_names

# %%
df_list, file_names=split_daily_transactions(df_filtered)

# %%
file_names
# Out:
# ['20191101',
#  '20191102',
#  '20191103',
#  '20191104',
#  '20191105',
#  '20191106',
#  '20191107',
#  '20191108',
#  '20191109',
#  '20191110']

# %% [markdown]
# Put together the preparation function

# %%
def prepare_new_transactions(path):
    
    cols = list(pd.read_csv(path, nrows=1))
    df=pd.read_csv(path,
                  usecols=[i for i in cols if 'Unnamed' not in i])
    
    #format time presenting hour as well
    df['problem_from_time']=df['FROM_TIME'].apply(lambda x: isTimeFormat(x) )
    df['problem_to_time']=df['TO_TIME'].apply(lambda x: isTimeFormat(x))
    df['problem_timestamp']=df['TIMESTAMP'].apply(lambda x: isTimeFormat(x))
    df['FROM_TIME']=df['FROM_TIME'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')
    df['TO_TIME']=df['TO_TIME'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')
    df['TIMESTAMP']=df['TIMESTAMP'].apply(lambda x: x if isTimeFormat(x) else str(x)+' 0:0')
    
    #convert to datetime
    df['FROM_TIME']=pd.to_datetime(df['FROM_TIME'],utc=True, format='%m/%d/%y %H:%M')
    df['TO_TIME']=pd.to_datetime(df['TO_TIME'],utc=True, format='%m/%d/%y %H:%M')
    df['TIMESTAMP']=pd.to_datetime(df['TIMESTAMP'], utc=True, format='%m/%d/%y %H:%M')
    
    #remove unusable columns
    df=df[df['problem_timestamp']]
    
    #modify dates mistakes
    df['FROM_TIME']=df.apply(lambda x: correct_from_time(x['problem_from_time'],x['TO_TIME'],x['FROM_TIME'], x['DURATION']), axis=1)
    df['TO_TIME']=df.apply(lambda x: correct_to_time(x['problem_to_time'],x['TO_TIME'],x['FROM_TIME'], x['DURATION']), axis=1)
    
    #define lead time
    df['lead_time']=df['FROM_TIME']-df['TIMESTAMP']
    
    # define logical statement to filter rows based on lead time
    logical_statement_lead_time = (df['lead_time'].dt.total_seconds(
    )/60 >= 30) & (df['lead_time'].dt.total_seconds()/60 <= 60)

    # filter the dataframe based on logical statement
    df_filtered = df[logical_statement_lead_time]
    
    #add columns for pipeline compatibility
    df_filtered['End Validity Date']=df_filtered['TIMESTAMP']
    df_filtered['Execution Price']=df_filtered['PRICE']
    df_filtered['Executed Volume']=df_filtered['VOLUME']
    df_filtered['Delivery Start']=df_filtered['FROM_TIME']
    df_filtered['Instrument Type']=df_filtered['DURATION'].apply(lambda x: map_duration(x))
    
    df_list, file_names=split_daily_transactions(df_filtered)
    
    return df_list

# %%
tic=time.time()
df_list_f=prepare_new_transactions('../data/external/prepared_EPEX_2019_Nov_Dec/ID_GDM_20191101.csv')
toc=time.time()
# Out:
# <ipython-input-47-b5e62a5e42ed>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['End Validity Date']=df_filtered['TIMESTAMP']
# <ipython-input-47-b5e62a5e42ed>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Execution Price']=df_filtered['PRICE']
# <ipython-input-47-b5e62a5e42ed>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Executed Volume']=df_filtered['VOLUME']
# <ipython-input-47-b5e62a5e42ed>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Delivery Start']=df_filtered['FROM_TIME']
# <ipython-input-47-b5e62a5e42ed>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['Instrument Type']=df_filtered['DURATION'].apply(lambda x: map_duration(x))

# %%
toc-tic
# Out:
# 127.00357103347778

# %%
df_list_f[0]
# Out:
#        DLVRYDATE MARKET_AREA_BUY MARKET_AREA_SELL                 FROM_TIME  \
# 199      11/1/19              DE               DE 2019-11-01 00:00:00+00:00
# 200      11/1/19              DE               DE 2019-11-01 00:00:00+00:00
# 201      11/1/19              DE               DE 2019-11-01 00:00:00+00:00
# 202      11/1/19              DE               DE 2019-11-01 00:00:00+00:00
# 203      11/1/19              DE               DE 2019-11-01 00:00:00+00:00
# ...          ...             ...              ...                       ...
# 122758   11/1/19              DE               DE 2019-11-01 23:45:00+00:00
# 122759   11/1/19              DE               DE 2019-11-01 23:45:00+00:00
# 122760   11/1/19              DE               DE 2019-11-01 23:45:00+00:00
# 305422   11/1/19              DE               DE 2019-11-01 14:00:00+00:00
# 305470   11/1/19              DE               DE 2019-11-01 14:00:00+00:00
#
#                          TO_TIME  VOLUME  PRICE                 TIMESTAMP  \
# 199    2019-11-01 01:00:00+00:00     3.1  31.00 2019-10-31 23:00:00+00:00
# 200    2019-11-01 01:00:00+00:00     0.4  30.01 2019-10-31 23:02:00+00:00
# 201    2019-11-01 01:00:00+00:00     0.7  30.02 2019-10-31 23:02:00+00:00
# 202    2019-11-01 01:00:00+00:00     0.2  31.17 2019-10-31 23:04:00+00:00
# 203    2019-11-01 01:00:00+00:00     0.4  31.23 2019-10-31 23:04:00+00:00
# ...                          ...     ...    ...                       ...
# 122758 2019-11-02 00:00:00+00:00     9.8  28.60 2019-11-01 23:14:00+00:00
# 122759 2019-11-02 00:00:00+00:00     1.0  26.90 2019-11-01 23:14:00+00:00
# 122760 2019-11-02 00:00:00+00:00     1.0  26.90 2019-11-01 23:15:00+00:00
# 305422 2019-11-01 15:00:00+00:00     1.0  34.20 2019-11-01 13:16:00+00:00
# 305470 2019-11-01 15:00:00+00:00     1.0  34.20 2019-11-01 13:17:00+00:00
#
#           TRADE_ID  DURATION                         PROD  problem_from_time  \
# 199     1080898285      1.00          Intraday_Hour_Power               True
# 200     1080898397      1.00          Intraday_Hour_Power               True
# 201     1080898396      1.00          Intraday_Hour_Power               True
# 202     1080898472      1.00          Intraday_Hour_Power               True
# 203     1080898473      1.00          Intraday_Hour_Power               True
# ...            ...       ...                          ...                ...
# 122758  1081014573      0.25  Intraday_Quarter_Hour_Power               True
# 122759  1081014572      0.25  Intraday_Quarter_Hour_Power               True
# 122760  1081014666      0.25  Intraday_Quarter_Hour_Power               True
# 305422  1080965900      1.00              XBID_Hour_Power               True
# 305470  1080966038      1.00              XBID_Hour_Power               True
#
#         problem_to_time  problem_timestamp       lead_time  \
# 199                True               True 0 days 01:00:00
# 200                True               True 0 days 00:58:00
# 201                True               True 0 days 00:58:00
# 202                True               True 0 days 00:56:00
# 203                True               True 0 days 00:56:00
# ...                 ...                ...             ...
# 122758             True               True 0 days 00:31:00
# 122759             True               True 0 days 00:31:00
# 122760             True               True 0 days 00:30:00
# 305422             True               True 0 days 00:44:00
# 305470             True               True 0 days 00:43:00
#
#                End Validity Date  Execution Price  Executed Volume  \
# 199    2019-10-31 23:00:00+00:00            31.00              3.1
# 200    2019-10-31 23:02:00+00:00            30.01              0.4
# 201    2019-10-31 23:02:00+00:00            30.02              0.7
# 202    2019-10-31 23:04:00+00:00            31.17              0.2
# 203    2019-10-31 23:04:00+00:00            31.23              0.4
# ...                          ...              ...              ...
# 122758 2019-11-01 23:14:00+00:00            28.60              9.8
# 122759 2019-11-01 23:14:00+00:00            26.90              1.0
# 122760 2019-11-01 23:15:00+00:00            26.90              1.0
# 305422 2019-11-01 13:16:00+00:00            34.20              1.0
# 305470 2019-11-01 13:17:00+00:00            34.20              1.0
#
#                   Delivery Start Instrument Type
# 199    2019-11-01 00:00:00+00:00            Hour
# 200    2019-11-01 00:00:00+00:00            Hour
# 201    2019-11-01 00:00:00+00:00            Hour
# 202    2019-11-01 00:00:00+00:00            Hour
# 203    2019-11-01 00:00:00+00:00            Hour
# ...                          ...             ...
# 122758 2019-11-01 23:45:00+00:00    Quarter Hour
# 122759 2019-11-01 23:45:00+00:00    Quarter Hour
# 122760 2019-11-01 23:45:00+00:00    Quarter Hour
# 305422 2019-11-01 14:00:00+00:00            Hour
# 305470 2019-11-01 14:00:00+00:00            Hour
#
# [21869 rows x 20 columns]

# %%
wp = read_weekly_prices_file(
        "../data/external/Hydro Generation and Price_CH_2019.csv")

# %%
wp.head()
# Out:
#                    End Date  Unnamed: 1  Summe von Generation [MWh]3  \
# 0 2019-01-06 00:00:00+00:00           1                       166734
# 1 2019-01-13 00:00:00+00:00           2                       414486
# 2 2019-01-20 00:00:00+00:00           3                       376949
# 3 2019-01-27 00:00:00+00:00           4                       575958
# 4 2019-02-03 00:00:00+00:00           5                       415389
#
#    Summe von Revenue [Û]  Max. von Generation [MWh]  \
# 0            10740712.41                       4707
# 1            28105388.19                       6826
# 2            24978865.93                       5758
# 3            44816423.67                       7158
# 4            26862029.56                       6484
#
#    Min. von Generation [MWh]2  Average Weekly Price [Euro/MWh]  \
# 0                         302                        64.418249
# 1                         391                        67.807811
# 2                         448                        66.265903
# 3                         416                        77.811965
# 4                         538                        64.667166
#
#    Max Weekly Pumping Price [Euro/MWh]                start_date
# 0                            51.534600 2018-12-30 00:00:00+00:00
# 1                            54.246248 2019-01-06 00:00:00+00:00
# 2                            53.012723 2019-01-13 00:00:00+00:00
# 3                            62.249572 2019-01-20 00:00:00+00:00
# 4                            51.733733 2019-01-27 00:00:00+00:00

# %%
wp.tail()
# Out:
#                     End Date  Unnamed: 1  Summe von Generation [MWh]3  \
# 48 2019-12-08 00:00:00+00:00          49                       432270
# 49 2019-12-15 00:00:00+00:00          50                       410218
# 50 2019-12-22 00:00:00+00:00          51                       286045
# 51 2019-12-29 00:00:00+00:00          52                       194045
# 52 2020-01-01 00:00:00+00:00          53                        99512
#
#     Summe von Revenue [Û]  Max. von Generation [MWh]  \
# 48            24068432.79                       6345
# 49            20140890.04                       6595
# 50            12831597.03                       6309
# 51             6281356.04                       4637
# 52             3703083.54                       4714
#
#     Min. von Generation [MWh]2  Average Weekly Price [Euro/MWh]  \
# 48                         409                        55.679165
# 49                         312                        49.098016
# 50                         259                        44.858666
# 51                         616                        32.370615
# 52                         587                        37.212432
#
#     Max Weekly Pumping Price [Euro/MWh]                start_date
# 48                            44.543332 2019-12-01 00:00:00+00:00
# 49                            39.278413 2019-12-08 00:00:00+00:00
# 50                            35.886933 2019-12-15 00:00:00+00:00
# 51                            25.896492 2019-12-22 00:00:00+00:00
# 52                            29.769946 2019-12-29 00:00:00+00:00

# %%
power_lim = read_pw_file(
    "../data/external/Hydro Generation up- downscale Potential_CH_2019.csv")
power_lim = pw_preparation(power_lim)

# %%
power_lim.head()
# Out:
#                  VALUE_TIME                start_time  \
# 0 2019-01-01 00:00:00+00:00 2019-01-01 00:00:00+00:00
# 1 2019-01-01 00:15:00+00:00 2019-01-01 00:15:00+00:00
# 2 2019-01-01 00:30:00+00:00 2019-01-01 00:30:00+00:00
# 3 2019-01-01 00:45:00+00:00 2019-01-01 00:45:00+00:00
# 4 2019-01-01 01:00:00+00:00 2019-01-01 01:00:00+00:00
#
#                    end_time Selling Actual value update [MW]  \
# 0 2019-01-01 00:15:00+00:00                             4145
# 1 2019-01-01 00:30:00+00:00                             4145
# 2 2019-01-01 00:45:00+00:00                             4145
# 3 2019-01-01 01:00:00+00:00                             4145
# 4 2019-01-01 01:15:00+00:00                             4238
#
#   Pumping Actual value update [MW] Upscale Potential [MW]  \
# 0                              260                   4145
# 1                              260                   4145
# 2                              260                   4145
# 3                              260                   4145
# 4                              167                   4238
#
#   Donwnscale Potential [MW]
# 0                       260
# 1                       260
# 2                       260
# 3                       260
# 4                       167

# %%
power_lim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35041 entries, 0 to 35040
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   VALUE_TIME                        35041 non-null  datetime64[ns, UTC]
#  1   start_time                        35041 non-null  datetime64[ns, UTC]
#  2   end_time                          35041 non-null  datetime64[ns, UTC]
#  3   Selling Actual value update [MW]  35041 non-null  object
#  4   Pumping Actual value update [MW]  35041 non-null  object
#  5   Upscale Potential [MW]            35041 non-null  object
#  6   Donwnscale Potential [MW]         35041 non-null  object
# dtypes: datetime64[ns, UTC](3), object(4)
# memory usage: 1.9+ MB

# %%
power_lim_selection = power_lim[(power_lim['start_time'].dt.day == 1) & (
            power_lim['start_time'].dt.month == 3)]

# %%
power_lim_selection.head()
# Out:
#                     VALUE_TIME                start_time  \
# 5664 2019-03-01 00:00:00+00:00 2019-03-01 00:00:00+00:00
# 5665 2019-03-01 00:15:00+00:00 2019-03-01 00:15:00+00:00
# 5666 2019-03-01 00:30:00+00:00 2019-03-01 00:30:00+00:00
# 5667 2019-03-01 00:45:00+00:00 2019-03-01 00:45:00+00:00
# 5668 2019-03-01 01:00:00+00:00 2019-03-01 01:00:00+00:00
#
#                       end_time Selling Actual value update [MW]  \
# 5664 2019-03-01 00:15:00+00:00                             5167
# 5665 2019-03-01 00:30:00+00:00                             5167
# 5666 2019-03-01 00:45:00+00:00                             5167
# 5667 2019-03-01 01:00:00+00:00                             5167
# 5668 2019-03-01 01:15:00+00:00                             5146
#
#      Pumping Actual value update [MW] Upscale Potential [MW]  \
# 5664                               36                   5167
# 5665                               36                   5167
# 5666                               36                   5167
# 5667                               36                   5167
# 5668                               57                   5146
#
#      Donwnscale Potential [MW]
# 5664                        36
# 5665                        36
# 5666                        36
# 5667                        36
# 5668                        57

# %%
power_lim_selection[power_lim_selection['Upscale Potential [MW]']==5167]
# Out:
#                     VALUE_TIME                start_time  \
# 5664 2019-03-01 00:00:00+00:00 2019-03-01 00:00:00+00:00
# 5665 2019-03-01 00:15:00+00:00 2019-03-01 00:15:00+00:00
# 5666 2019-03-01 00:30:00+00:00 2019-03-01 00:30:00+00:00
# 5667 2019-03-01 00:45:00+00:00 2019-03-01 00:45:00+00:00
#
#                       end_time Selling Actual value update [MW]  \
# 5664 2019-03-01 00:15:00+00:00                             5167
# 5665 2019-03-01 00:30:00+00:00                             5167
# 5666 2019-03-01 00:45:00+00:00                             5167
# 5667 2019-03-01 01:00:00+00:00                             5167
#
#      Pumping Actual value update [MW] Upscale Potential [MW]  \
# 5664                               36                   5167
# 5665                               36                   5167
# 5666                               36                   5167
# 5667                               36                   5167
#
#      Donwnscale Potential [MW]
# 5664                        36
# 5665                        36
# 5666                        36
# 5667                        36

# %%
power_lim_selection['Upscale Potential [MW]']=power_lim_selection['Upscale Potential [MW]'].astype('float')
# Out:
# <ipython-input-86-51514ab751d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   power_lim_selection['Upscale Potential [MW]']=power_lim_selection['Upscale Potential [MW]'].astype('float')

# %%
power_lim_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 5664 to 5759
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   VALUE_TIME                        96 non-null     datetime64[ns, UTC]
#  1   start_time                        96 non-null     datetime64[ns, UTC]
#  2   end_time                          96 non-null     datetime64[ns, UTC]
#  3   Selling Actual value update [MW]  96 non-null     object
#  4   Pumping Actual value update [MW]  96 non-null     object
#  5   Upscale Potential [MW]            96 non-null     float64
#  6   Donwnscale Potential [MW]         96 non-null     object
# dtypes: datetime64[ns, UTC](3), float64(1), object(3)
# memory usage: 8.1+ KB

# %%
power_lim_selection.groupby(power_lim_selection['start_time'].dt.hour)['Upscale Potential [MW]'].mean()
# Out:
# start_time
# 0     5167.0
# 1     5146.0
# 2     5123.0
# 3     5179.0
# 4     5103.0
# 5     4954.0
# 6     4077.0
# 7     2884.0
# 8     2262.0
# 9     2209.0
# 10    2788.0
# 11    2410.0
# 12    2768.0
# 13    3822.0
# 14    4160.0
# 15    3947.0
# 16    3282.0
# 17    1904.0
# 18     584.0
# 19    1021.0
# 20    3571.0
# 21    4340.0
# 22    4432.0
# 23    4897.0
# Name: Upscale Potential [MW], dtype: float64

# %%
power_lim_selection['Donwnscale Potential [MW]']
# Out:
# 5664     0
# 5665     0
# 5666     0
# 5667     0
# 5668     1
#         ..
# 5755    22
# 5756    23
# 5757    23
# 5758    23
# 5759    23
# Name: start_time, Length: 96, dtype: int64
